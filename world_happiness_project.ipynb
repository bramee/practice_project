# %% [markdown]
# Importing the required libraries

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix,classification_report,accuracy_score
from sklearn.preprocessing import StandardScaler,LabelEncoder
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score
from sklearn.metrics import mean_squared_error
from scipy.stats import zscore
import seaborn as sns
import matplotlib.pyplot as plt


import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("happiness.csv") 
df
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# ...

# %% [markdown]
# Changing the categorical code into numeric using Label Encoder.

# %%
le = LabelEncoder()
df['Country'] = le.fit_transform(df['Country'])
df['Region'] = le.fit_transform(df['Region'])
df
# Out:
#      Country  Region  Happiness Rank  Happiness Score  Standard Error  \
# 0        135       9               1            7.587         0.03411
# 1         58       9               2            7.561         0.04884
# 2         37       9               3            7.527         0.03328
# 3        105       9               4            7.522         0.03880
# 4         24       5               5            7.427         0.03553
# ..       ...     ...             ...              ...             ...
# 153      118       8             154            3.465         0.03464
# 154       13       8             155            3.340         0.03656
# 155      136       4             156            3.006         0.05015
# 156       21       8             157            2.905         0.08658
# 157      141       8             158            2.839         0.06727
#
#      Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# ...

# %%
df.describe()
# Out:
#           Country      Region  Happiness Rank  Happiness Score  \
# count  158.000000  158.000000      158.000000       158.000000
# mean    78.500000    5.120253       79.493671         5.375734
# std     45.754781    2.993321       45.754363         1.145010
# min      0.000000    0.000000        1.000000         2.839000
# 25%     39.250000    3.000000       40.250000         4.526000
# 50%     78.500000    4.500000       79.500000         5.232500
# 75%    117.750000    8.000000      118.750000         6.243750
# max    157.000000    9.000000      158.000000         7.587000
#
#        Standard Error  Economy (GDP per Capita)      Family  \
# count      158.000000                158.000000  158.000000
# mean         0.047885                  0.846137    0.991046
# std          0.017146                  0.403121    0.272369
# min          0.018480                  0.000000    0.000000
# 25%          0.037268                  0.545808    0.856823
# ...

# %%
df.isnull().sum()
# Out:
# Country                          0
# Region                           0
# Happiness Rank                   0
# Happiness Score                  0
# Standard Error                   0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# dtype: int64

# %% [markdown]
# As there is no null values,data is pretty cleaned.

# %%
x1 = df.drop(columns=['Happiness Score'])
y = df['Happiness Score']

# %%
x1
# Out:
#      Country  Region  Happiness Rank  Standard Error  \
# 0        135       9               1         0.03411
# 1         58       9               2         0.04884
# 2         37       9               3         0.03328
# 3        105       9               4         0.03880
# 4         24       5               5         0.03553
# ..       ...     ...             ...             ...
# 153      118       8             154         0.03464
# 154       13       8             155         0.03656
# 155      136       4             156         0.05015
# 156       21       8             157         0.08658
# 157      141       8             158         0.06727
#
#      Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                     1.39651  1.34951                   0.94143  0.66557
# 1                     1.30232  1.40223                   0.94784  0.62877
# 2                     1.32548  1.36058                   0.87464  0.64938
# ...

# %%
x1_cont = df[x1.columns[2:12]]
x1_cont
# Out:
#      Happiness Rank  Standard Error  Economy (GDP per Capita)   Family  \
# 0                 1         0.03411                   1.39651  1.34951
# 1                 2         0.04884                   1.30232  1.40223
# 2                 3         0.03328                   1.32548  1.36058
# 3                 4         0.03880                   1.45900  1.33095
# 4                 5         0.03553                   1.32629  1.32261
# ..              ...             ...                       ...      ...
# 153             154         0.03464                   0.22208  0.77370
# 154             155         0.03656                   0.28665  0.35386
# 155             156         0.05015                   0.66320  0.47489
# 156             157         0.08658                   0.01530  0.41587
# 157             158         0.06727                   0.20868  0.13995
#
#      Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# ...

# %% [markdown]
# visualizing the Box plot to check outliers / skewness

# %%
plt.figure(figsize=(15,20))
graph=1

for col in x1_cont:
    if graph<=12:
        ax = plt.subplot(4,3,graph)
        sns.boxplot(x1_cont[col],orient ='v')
        plt.xlabel(col,fontsize=7)
    graph+=1
plt.show()

# %% [markdown]
# Separating the Continuous data and categorical data and Applying skewness to continuous data and concating with categorical data  later

# %%
x1_cont.shape
# Out:
# (158, 9)

# %%
x1_cat = df[x1.columns[0:2]]
x1_cat
# Out:
#      Country  Region
# 0        135       9
# 1         58       9
# 2         37       9
# 3        105       9
# 4         24       5
# ..       ...     ...
# 153      118       8
# 154       13       8
# 155      136       4
# 156       21       8
# 157      141       8
#
# [158 rows x 2 columns]

# %%
x1_cont.skew()
# Out:
# Happiness Rank                   0.000418
# Standard Error                   1.983439
# Economy (GDP per Capita)        -0.317575
# Family                          -1.006893
# Health (Life Expectancy)        -0.705328
# Freedom                         -0.413462
# Trust (Government Corruption)    1.385463
# Generosity                       1.001961
# Dystopia Residual               -0.238911
# dtype: float64

# %%
corr_mat = x1_cont.corr()
corr_mat
# Out:
#                                Happiness Rank  Standard Error  \
# Happiness Rank                       1.000000        0.158516
# Standard Error                       0.158516        1.000000
# Economy (GDP per Capita)            -0.785267       -0.217651
# Family                              -0.733644       -0.120728
# Health (Life Expectancy)            -0.735613       -0.310287
# Freedom                             -0.556886       -0.129773
# Trust (Government Corruption)       -0.372315       -0.178325
# Generosity                          -0.160142       -0.088439
# Dystopia Residual                   -0.521999        0.083981
#
#                                Economy (GDP per Capita)    Family  \
# Happiness Rank                                -0.785267 -0.733644
# Standard Error                                -0.217651 -0.120728
# Economy (GDP per Capita)                       1.000000  0.645299
# Family                                         0.645299  1.000000
# ...

# %% [markdown]
# Using POWER-TRANSFORM method, We are removing the skewness

# %%
from sklearn.preprocessing import power_transform
df_new = power_transform(x1_cont, method ='yeo-johnson')

df_new= pd.DataFrame(df_new,columns=x1_cont.columns)

# %%
df_new.skew()
# Out:
# Happiness Rank                  -0.264365
# Standard Error                  -0.020092
# Economy (GDP per Capita)        -0.127233
# Family                          -0.169651
# Health (Life Expectancy)        -0.183181
# Freedom                         -0.080728
# Trust (Government Corruption)    0.185965
# Generosity                       0.013320
# Dystopia Residual                0.022925
# dtype: float64

# %%
x = pd.concat([x1_cat,df_new],axis =1)
x.head()
# Out:
#    Country  Region  Happiness Rank  Standard Error  Economy (GDP per Capita)  \
# 0      135       9       -2.063414       -0.972226                  1.446061
# 1       58       9       -2.008498        0.309350                  1.173321
# 2       37       9       -1.958574       -1.062017                  1.239836
# 3      105       9       -1.912062       -0.503610                  1.630246
# 4       24       5       -1.868100       -0.823548                  1.242168
#
#      Family  Health (Life Expectancy)   Freedom  \
# 0  1.669206                  1.491765  1.756335
# 1  2.012132                  1.532348  1.439946
# 2  1.739586                  1.085223  1.615733
# 3  1.553118                  1.147600  1.792821
# 4  1.501726                  1.270179  1.475479
#
#    Trust (Government Corruption)  Generosity  Dystopia Residual
# 0                       1.773991    0.622391           0.750992
# 1                       0.315993    1.480995           1.110011
# ...

# %%
scalar = StandardScaler()
x_sc = scalar.fit_transform(x)

# %%
x
# Out:
#      Country  Region  Happiness Rank  Standard Error  \
# 0        135       9       -2.063414       -0.972226
# 1         58       9       -2.008498        0.309350
# 2         37       9       -1.958574       -1.062017
# 3        105       9       -1.912062       -0.503610
# 4         24       5       -1.868100       -0.823548
# ..       ...     ...             ...             ...
# 153      118       8        1.490877       -0.916014
# 154       13       8        1.508130       -0.719479
# 155      136       4        1.525352        0.399137
# 156       21       8        1.542544        1.926902
# 157      141       8        1.559705        1.310323
#
#      Economy (GDP per Capita)    Family  Health (Life Expectancy)   Freedom  \
# 0                    1.446061  1.669206                  1.491765  1.756335
# 1                    1.173321  2.012132                  1.532348  1.439946
# 2                    1.239836  1.739586                  1.085223  1.615733
# ...

# %%
x_train,x_test,y_train,y_test = train_test_split(x_sc,y,test_size =0.25,random_state = 420)

# %% [markdown]
# Building new models and training and predicting the model

# %%
from sklearn.linear_model import LinearRegression

lr = LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(x_test)

# %%
tr_score = lr.score(x_train,y_train) #adj.r2 accuracy
tr_score
# Out:
# 0.9939869668941306

# %%
mean_squared_error(y_test,y_pred)
# Out:
# 0.010321707953200024

# %%
from sklearn.ensemble import RandomForestRegressor

rfr = RandomForestRegressor()
rfr.fit(x_train,y_train)
y_pred = rfr.predict(x_test)

# %%
rftr_score = rfr.score(x_train,y_train) #adj.r2 accuracy
rftr_score
# Out:
# 0.9994829994554529

# %%
mean_squared_error(y_test,y_pred)
# Out:
# 0.0012713008050000293

# %%
from sklearn.tree import DecisionTreeRegressor

dt = DecisionTreeRegressor()
dt.fit(x_train,y_train)
y_pred = dt.predict(x_test)

# %%
dt_score = dt.score(x_train,y_train)  #adj.r2 accuracy
dt_score
# Out:
# 1.0

# %%
mean_squared_error(y_test,y_pred)
# Out:
# 0.002847450000000007

# %%
scr = cross_val_score(lr,x_sc,y,cv=5)
print("CV Score of LR :", scr.mean())
# Out:
# CV Score of LR : 0.7673755211318386

# %%
scr = cross_val_score(dt,x_sc,y,cv=5)
print("CV Score of DT :", scr.mean())
# Out:
# CV Score of DT : -1.3083557509503336

# %%
scr = cross_val_score(rfr,x_sc,y,cv=5)
print("CV Score of DT :", scr.mean())
# Out:
# CV Score of DT : -1.7187026093750348

# %% [markdown]
# Based on CV score,Linear regression model has highest score of 76%

# %%
from sklearn.linear_model import Lasso,LassoCV

# %%
lasscv = LassoCV(alphas = None, max_iter = 1000, normalize = True)
lasscv.fit(x_train, y_train)
# Out:
# LassoCV(normalize=True)

# %%
alpha = lasscv.alpha_
alpha
# Out:
# 0.00010390452846687023

# %%
lasso_reg = Lasso(alpha)
lasso_reg.fit(x_train,y_train)
# Out:
# Lasso(alpha=0.00010390452846687023)

# %%
lasso_reg.score(x_test,y_test)
# Out:
# 0.9920222397667332
